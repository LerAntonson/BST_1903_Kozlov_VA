# %% [markdown]
# # Лабораторная робота №1
# ## Выполнил студент группы БСТ_1903 Козлов В.А
# ### Задание №1

# %%
print("Hello, Wolrd")
# Out:
# Hello, Wolrd

# %% [markdown]
# ### Задание №2
# # Написать генератор случайных матриц(многомерных)

# %%
import numpy
import time
def matrixgenerate():
    n=int(input())
    m=int(input())
    matrixx = numpy.random.random_integers(-250, 1007, size=(n, m))
    print(*matrixx)
    return matrixx

# %% [markdown]
# ### Задание №2
# # Реализовать методы сортировки строк числовой матрицы методом:вставки, выбором, обменом, Шелла, турнирной, быстрой сортировкой, пирамидальной

# %%
def sortviborom(matrixx):
    matrline=per(matrixx)
    for i in range(0, len(matrline)):
        for j in range(i, len(matrline)):
            if matrline[i]>matrline[j]:
                matrline[i], matrline[j]=matrline[j], matrline[i]     
    return vivod(matrixx, matrline)

# %%
def sortvstavkami(matrixx):
    matrline=per(matrixx)
    for i in range(1, len(matrline)):
        j=i-1
        while (j>=0) and (matrline[j]>matrline[j+1]):
            matrline[j], matrline[j+1]=matrline[j+1], matrline[j]
            j=j-1
    return vivod(matrixx, matrline)

# %%
def sortobmen(matrixx):
    matrline=per(matrixx)
    l=len(matrline)
    while l>1:
        for i in range(l-1):
            if matrline[i]>matrline[i+1]:
                matrline[i], matrline[i+1]=matrline[i+1], matrline[i]
        l=l-1
        
    return vivod(matrixx, matrline)

# %%
def shellsort(matrixx):
    matrline=per(matrixx)
    length=len(matrline)
    l=length
    while l>0:
        for i in range(length-l):
            j=i
            while j>=0 and matrline[j+l]<matrline[j]:
                    matrline[j], matrline[j+l]=matrline[j+l], matrline[j]
                    j=j-l
        l=int(l/2)
    return vivod(matrixx, matrline)

# %%
def tyrsort(matrixx):
    matrline=per(matrixx)
    def _tyrsort(matrline):
        tree = [None] * 2 * (len(matrline) + len(matrline) % 2)
        index = len(tree) - len(matrline) - len(matrline) % 2
        for i, v in enumerate(matrline):
            tree[index + i] = (i, v)
        for j in range(len(matrline)):
            n = len(matrline)
            index = len(tree) - len(matrline) - len(matrline) % 2
            while index > -1:
                n = (n + 1) // 2
                for i in range(n):
                    i = max(index + i * 2, 1)
                    if tree[i] != None and tree[i + 1] != None:
                        if tree[i][1] < tree[i + 1][1]:
                            tree[i // 2] = tree[i]
                        else:
                            tree[i // 2] = tree[i + 1]
                    else:
                        tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
                index -= n

            index, x = tree[0]
            matrline[j] = x
            tree[len(tree) - len(matrline) - len(matrline) % 2 + index] = None
    _tyrsort(matrline)
    return vivod(matrixx, matrline)

# %%
def qs(matrixx):
    matrline=per(matrixx)
    def quicksort(matrline, first, last):
        i=first
        j=last
        x=matrline[int((first+last)/2)]
        while i<=j:
            while matrline[i]<x:
                i+=1
            while matrline[j]>x:
                j-=1
            if i<=j:
                if matrline[i]>matrline[j]:
                    matrline[i], matrline[j]=matrline[j], matrline[i]
                i+=1
                j-=1
        if i<last:
            quicksort(matrline, i, last)
        if first<j:
            quicksort(matrline, first, j)
    quicksort(matrline, 0, len(matrline)-1)
    return vivod(matrixx, matrline)

# %%
def heapSort(matrixx):
    matrline=per(matrixx)
    def downHeap(matrline, k, n):
        el = matrline[k]
        while 2*k+1 < n:
            child = 2*k+1
            if child+1 < n and matrline[child] < matrline[child+1]:
                child += 1
            if el >= matrline[child]:
                break
            matrline[k] = matrline[child]
            k = child
        matrline[k] = el
  
    size = len(matrline)
    for i in range(size//2-1,-1,-1):
        downHeap(matrline, i, size)
    for i in range(size-1,0,-1):
        temp = matrline[i]
        matrline[i] = matrline[0]
        matrline[0] = temp
        downHeap(matrline, 0, i)
    return vivod(matrixx, matrline)

# %%
def per(matrixx):
    n=len(matrixx)
    m=len(matrixx[0])
    matrline=[0]*(n*m)
    x=int(0)
    for i in range(0, n):
        for j in range(0, m):
            matrline[x]=matrixx[i][j]
            x=x+1
    return matrline

def vivod(matrixx, matrline):
    n=len(matrixx)
    m=len(matrixx[0])
    x=int(0)
    matrix=[[0] * m for i in range(n)]
    for i in range(0, n):
        for j in range(0, m):
            matrix[i][j]=matrline[x]
            x=x+1
    return matrix

# %%
matrixx=matrixgenerate()

#Стандартная сортировка
timerStart = time.perf_counter()
matrline=per(matrixx)
matrline=sorted(matrline)
matrixstandart=vivod(matrixx, matrline)
timerEnd = time.perf_counter()
timer1 = timerEnd - timerStart
#

#Сортировка выбором
timerStart = time.perf_counter()
matrix=sortviborom(matrixx)
timerEnd = time.perf_counter()
timer2 = timerEnd - timerStart
#

#Сортировка вставками
timerStart = time.perf_counter()
matrix1=sortvstavkami(matrixx)
timerEnd = time.perf_counter()
timer3 = timerEnd - timerStart
#

#Сортировка обменом
timerStart = time.perf_counter()
matrix2=sortobmen(matrixx)
timerEnd = time.perf_counter()
timer4 = timerEnd - timerStart
#

#Сортировка Шелла
timerStart = time.perf_counter()
matrix3=shellsort(matrixx)
timerEnd = time.perf_counter()
timer5 = timerEnd - timerStart
#
#Турнирная сортировка
timerStart = time.perf_counter()
matrix4=tyrsort(matrixx)
timerEnd = time.perf_counter()
timer6 = timerEnd - timerStart
#

#Быстрая сортировка
timerStart = time.perf_counter()
matrix5=qs(matrixx)
timerEnd = time.perf_counter()
timer7 = timerEnd - timerStart
#

#Пирамидальная сортировка
timerStart = time.perf_counter()
matrix6=heapSort(matrixx)
timerEnd = time.perf_counter()
timer8 = timerEnd - timerStart
#
print("\nВремя работы стандартной сортировки", timer1,"\nРезультат сортировки\n", *matrixstandart)
print("\nВремя работы сортировки выбором", timer2,"\nРезультат сортировки\n", *matrix)
print("\nВремя работы сортировки вставкой", timer3,"\nРезультат сортировки\n", *matrix1)
print("\nВремя работы сортировки обменом", timer4,"\nРезультат сортировки\n", *matrix2)
print("\nВремя работы сортировки Шелла", timer5,"\nРезультат сортировки\n", *matrix3)
print("\nВремя работы турнирной сортировки", timer6,"\nРезультат сортировки\n", *matrix4)
print("\nВремя работы быстрой сортировки", timer7,"\nРезультат сортировки\n", *matrix5)
print("\nВремя работы пирамидальной сортировки", timer8,"\nРезультат сортировки\n", *matrix6)
# Out:
#  50
#  50
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning
#   762  350  560  774  550  447  133  281] [ 853  517  494  923  398  -48  508  371  347  197 -101  994  454   89
#   805  204  781  969  545 -203  316  321  428  890  334  681  499 -109
#   499  674 -198  958   21   67  343  221  957  673  470  359  283  715
#  -212  456  612  646  815  555 -133  492] [-222  144 -148  562  779 -116  738  -94  816  880  386  880 -243  292
#   854  308  714  586  876   82  603  980  914  250  732  859  598  330
#  -170  979  902  571   88 -214  874 -132  793 -239 -231   21  -45  914
#   198  975  -88  774  460  663  541  161] [ 512  340  443  818 -247  700 -152  360   66  957  805   76  648  767
#   410   70  289  983  905  521  849  364 -217  580  413  304 -175  440
#   371  579  118  668  203  311  631  -87  233  644  553   36 -103  763
#   668  240  873  189  977  843  326  949] [ 414  -70  241  237  435   92  750 -143  471  611   83  601  619  572
#   239 -219   48  842  214  459  380  539 -197   66 -191  616  955  649
#    70  667  -44  835  621  883  892  649  496  942  885  262  656 -210
#   763  712  627  176  539 -143  194  685] [ 617  762 -101  155  226  640  -61 -231    6  910   -2   64  673  764
#   575  303  343  434  890  758  -32  988 -246  200  574  724  372   36
#  -205  180   89  426  350  529  469  632  228  143  584  167  991  408
#   901  117  374  977  138  182  350 -202] [ 805  168  879  946  227  189  235 -240  840  268  472 -241  -32  342
#   743 -182  -91  764    5 -170  382  492  636  532  126  584  895  601
#   926  512   55 -222  718  682  778  115  230    0 -144  675  376  -58
#   445  971  489  -28  333 -240  526  870] [ 935  925  966   61  595  153  702  203  248  912 -103  708  644  -12
#   454  879  636  -69  252 -180  813 -110 -199  533 -132 -230 -238  271
#    60  821  250  541  554  -75  574 -125 1006   97  726  425  880  252
#   801  559 -192  717  974  319  781  242] [ 311 -173   27  530  601  648 -245  270  290  757  857 -110  -84  511
#   498  289  172  576 1003  -18   48  305  584  -32  700  799  178  904
#    76  608  849  675   74  -39  240  156   14  357 -161  561  146  452
#   113  151  466  899  252  452  -89  546] [ 710  144   74  549  506 -184 -113  828  -35  755   73  475  759 -220
#   673  728   20  461  733   52 -149  633  755  487  703  537  141 -126
#   475  808  516  925  876  258  923   57   80  151   99  500  601  389
#  -187  773   27 -246  368  990 -133  759] [ 648  447  731 -139  531  164 -135 -249  544  903  947  465  757  367
#  -248  505  968  261  340  296 -112  340  720   -6  685  -54 -207  424
#   454  245 -180 -135  228  488 -129 -187  602  303  593  150  196  606
#   733  -86  509  917  102  265 -230  406]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-402543b569ea> in <module>
#      39 #Турнирная сортировка
#      40 timerStart = time.perf_counter()
# ---> 41 matrix4=tyrsort(matrixx)
#      42 timerEnd = time.perf_counter()
#      43 timer6 = timerEnd - timerStart
#
# <ipython-input-7-5052dfca4aa0> in tyrsort(matrixx)
#      25             matrline[j] = x
#      26             tree[len(tree) - len(matrline) - len(matrline) % 2 + index] = None
# ---> 27     _tyrsort(matrline)
#      28     return vivod(matrixx, matrline)
#
# <ipython-input-7-5052dfca4aa0> in _tyrsort(matrline)
#      22                 index -= n
#      23
# ---> 24             index, x = tree[0]
#      25             matrline[j] = x
#      26             tree[len(tree) - len(matrline) - len(matrline) % 2 + index] = None
#
# TypeError: cannot unpack non-iterable NoneType object
